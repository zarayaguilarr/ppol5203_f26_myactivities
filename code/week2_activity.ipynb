# %% [markdown]
# <h1><center> PPOL 5203 Data Science I: Foundations <br><br>
# <font color='grey'>Week 2: Practice Exercise<br><br>

# %% [markdown]
# # Activity 1: cloning and editing a repo
#
# 1. Create a new public repo using GitHub.com, calling it ppol5203_f26_myactivities
# 2. Clone the repo locally
# 3. Create a code/ subdirectory
# 4. Move this python notebook to the code/subdirectory, naming it "week2_activity.ipynb"
# 5. Add, commit, and push the changes with the following message "Code changes"
# 6. Create an output/ subdirectory
# 7. Within the output/ subdirectory, use touch to create a blank file
# 8. Add, commit, and push the changes with the following message "Output updates"
# 9. Using the GitHub website, edit the README to include a link to your code subdirectory (you can just copy and paste the link)

# %% [markdown]
# # Activity 2: incorporating remote changes
#
# 1. Make another change to your remote README using the GitHub website
# 2. Use git pull to pull the remote changes down
# 3. Edit the README locally
# 4. Use git add, commit, and push to push the local changes up - confirm via the web interface that they went through
